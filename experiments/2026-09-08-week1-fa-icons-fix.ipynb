# %% [markdown]
# # Week1 FA icon fix experiment
#
# Timestamp: 2026-09-09
#
# Intent: Week1 lunch generator: base it on original FA-CDN version and replace non-existent FA6 icon classes (fa-pasta, fa-bowl-hot, fa-bowl, fa-hamburger) with real FA 6.4.0 free solid classes.

# %% [markdown]
# ## Method and result
#
# Icon classes verified against FA 6.4.0 free solid set; mapping: Pasta→fa-bowl-food, Ramen→fa-bowl-rice, Soup→fa-mug-hot, Burger→fa-burger; visual style and logic unchanged.

# %% [markdown]
# Soup icon changed from fa-mug-hot to fa-bowl-food per user request (2026-09-09); duplicates Pasta icon.
